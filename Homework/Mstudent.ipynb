# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/MStudents.csv')

# %%
df
# Out:
#     Hours  Sleep(Hours)  Marks
# 0       0             6     34
# 1       1             7     36
# 2       1             8     33
# 3       1             6     39
# 4       1             7     42
# 5       2             7     45
# 6       2             8     38
# 7       3             6     45
# 8       3             7     53
# 9       3             8     46
# 10      3             6     56
# 11      4             7     59
# 12      4             7     55
# 13      4             8     56
# 14      5             6     72
# 15      5             7     59
# 16      6             8     62
# 17      6             6     71
# 18      7             7     78
# 19      7             7     88
# 20      7             8     61
# 21      7             6     74
# 22      8             7     71
# 23      8             8     89
# 24      9             6     82
# 25      9             7     67
# 26      9             7     89
# 27     10             8     81
# 28     10             7     82
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Hours         30 non-null     int64
#  1   Sleep(Hours)  30 non-null     int64
#  2   Marks         30 non-null     int64
# dtypes: int64(3)
# memory usage: 848.0 bytes

# %%
df.dtypes
# Out:
# Hours           int64
# Sleep(Hours)    int64
# Marks           int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Hours           0
# Sleep(Hours)    0
# Marks           0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.jointplot(x='Sleep(Hours)',y='Marks',data=df)

# %%
sns.distplot(df['Marks'])
# Out:
# <ipython-input-12-f8cf80aed228>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Marks'])
# <Axes: xlabel='Marks', ylabel='Density'>

# %%
sns.boxplot(x='Hours',y='Marks',data=df)
# Out:
# <Axes: xlabel='Hours', ylabel='Marks'>

# %%
sns.countplot(x='Hours',data=df)
# Out:
# <Axes: xlabel='Hours', ylabel='count'>

# %%
sns.barplot(x='Sleep(Hours)',y='Marks',data=df)
# Out:
# <Axes: xlabel='Sleep(Hours)', ylabel='Marks'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
df.iloc[:,1:-1]=sc.fit_transform(df.iloc[:,1:-1])

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
y
# Out:
# 0     34
# 1     36
# 2     33
# 3     39
# 4     42
# 5     45
# 6     38
# 7     45
# 8     53
# 9     46
# 10    56
# 11    59
# 12    55
# 13    56
# 14    72
# 15    59
# 16    62
# 17    71
# 18    78
# 19    88
# 20    61
# 21    74
# 22    71
# 23    89
# 24    82
# 25    67
# 26    89
# 27    81
# 28    82
# 29    79
# Name: Marks, dtype: int64

# %%
x
# Out:
#     Hours  Sleep(Hours)
# 0       0     -1.369306
# 1       1      0.000000
# 2       1      1.369306
# 3       1     -1.369306
# 4       1      0.000000
# 5       2      0.000000
# 6       2      1.369306
# 7       3     -1.369306
# 8       3      0.000000
# 9       3      1.369306
# 10      3     -1.369306
# 11      4      0.000000
# 12      4      0.000000
# 13      4      1.369306
# 14      5     -1.369306
# 15      5      0.000000
# 16      6      1.369306
# 17      6     -1.369306
# 18      7      0.000000
# 19      7      0.000000
# 20      7      1.369306
# 21      7     -1.369306
# 22      8      0.000000
# 23      8      1.369306
# 24      9     -1.369306
# 25      9      0.000000
# 26      9      0.000000
# 27     10      1.369306
# 28     10      0.000000
# 29     11      0.000000

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=123)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 5.39158893, -2.27742479])

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([53.09253686, 93.10675594, 44.58245561, 82.32357809, 49.97404454,
#        84.59667469, 55.36563346, 74.65889257, 55.36563346])

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
rmse = mean_squared_error(y_test,y_pred,squared=False)

# %%
rmse
# Out:
# 6.192357221375134

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8421443217866204
