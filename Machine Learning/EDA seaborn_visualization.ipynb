# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df.head() # here "tips" is dependent featutre and others are independent feature
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
z=df.corr() # for correlation.
z
# Out:
# <ipython-input-12-e8fce7b79840>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   z=df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(z,annot=True) #heatmap for graph, annot for the values to show in graph is a-notation.
# Out:
# <Axes: >

# %%
sns.jointplot(x='tip',y='total_bill',data=df,hue='sex') #hue is parameter of two different values.

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='day')

# %%
sns.pairplot(df,hue='time')

# %%
sns.distplot(df['tip'])
# Out:
# <ipython-input-26-3f4491b3d128>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.countplot(x=df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(y=df['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(x=df['smoker'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x=df['day'])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x=df['day'],hue=df['time'])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(y=df['day'])
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.barplot(x='day',y='total_bill',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(x='day',y='total_bill',data=df,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ***Practise***

# %%
import seaborn as ab

# %%
ab.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=ab.load_dataset('planets')

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
a=df.corr() # for correlation.
a
# Out:
# <ipython-input-8-308927132a7b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a=df.corr() # for correlation.
#                   number  orbital_period      mass  distance      year
# number          1.000000       -0.012570 -0.241429 -0.033638  0.147849
# orbital_period -0.012570        1.000000  0.173725 -0.034365 -0.032333
# mass           -0.241429        0.173725  1.000000  0.274082 -0.123787
# distance       -0.033638       -0.034365  0.274082  1.000000  0.178922
# year            0.147849       -0.032333 -0.123787  0.178922  1.000000

# %%
ab.heatmap(a,annot=True)
# Out:
# <Axes: >

# %%
ab.jointplot(x='mass',y='distance',data=df,hue='year') #hue is parameter of two different values.

# %%
ab.pairplot(df)

# %%
ab.pairplot(df,hue='number')

# %%
ab.distplot(df['orbital_period'])
# Out:
# <ipython-input-14-22ef811532c2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ab.distplot(df['orbital_period'])
# <Axes: xlabel='orbital_period', ylabel='Density'>

# %%
ab.histplot(df['mass'])
# Out:
# <Axes: xlabel='mass', ylabel='Count'>

# %%
ab.countplot(y=df['year'])
# Out:
# <Axes: xlabel='count', ylabel='year'>

# %%
ab.countplot(y=df['year'],hue=df['mass'])
# Out:
# <Axes: xlabel='count', ylabel='year'>

# %%
ab.barplot(x='year',y='distance',data=df,hue='mass')
# Out:
# <Axes: xlabel='year', ylabel='distance'>

# %%
ab.boxplot(x='year',y='orbital_period',data=df)
# Out:
# <Axes: xlabel='year', ylabel='orbital_period'>

# %%
ab.boxplot(df)
# Out:
# <Axes: >

# %%
ab.boxplot(x='year',y='mass',data=df,hue='distance')
# Out:
# <Axes: xlabel='year', ylabel='mass'>

# %%
ab.violinplot(x='year',y='mass',data=df)
# Out:
# <Axes: xlabel='year', ylabel='mass'>

# %%
ab.violinplot(x='year',y='mass',data=df,hue='distance')
# Out:
# <Axes: xlabel='year', ylabel='mass'>

# %% [markdown]
# ***Come again...***
