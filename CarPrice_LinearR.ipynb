# %% [markdown]
# # Importing

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Reading file

# %%
df=pd.read_csv('/content/drive/MyDrive/CarPrice.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Knowing data

# %%
df.head() # it will show first 5 rows
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info() # it will give information about
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.shape # its give size of data i.e. 205 rows and 26 columns
# Out:
# (205, 26)

# %%
df.describe() #Its give count, mean, std etc for numerical feature
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.isnull().sum() # its give total missing values in column
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# # Preforming EDA

# %%
z=df.corr() # its shows the correlation of features
z
# Out:
# <ipython-input-15-bcd0cdc6a9ef>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   z=df.corr() # its shows the correlation of features
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# ...

# %%
sns.jointplot(x='carlength',y='carwidth',data=df)

# %%
sns.distplot(df['price'])
# Out:
# <ipython-input-17-86c1ddc3c66a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# The data is distributed in left skeweed data

# %%
sns.boxplot(x='enginetype',y='price',data=df)
# Out:
# <Axes: xlabel='enginetype', ylabel='price'>

# %% [markdown]
# The box represents the distribution of prices for a specific engine type.

# %%
sns.countplot(x='enginetype',data=df)
# Out:
# <Axes: xlabel='enginetype', ylabel='count'>

# %% [markdown]
# 1] Most of the car in this dataset uses ohc engintype and
# 2] the maximum engintype  is ohc
# 3] the minimum engintype is dohcv

# %%
sns.barplot(x='fueltype',y='price',data=df)
# Out:
# <Axes: xlabel='fueltype', ylabel='price'>

# %% [markdown]
# diesel price is higher than gas price

# %% [markdown]
# # Deleting Columns in data

# %%
df.drop(['car_ID','CarName'],axis=1,inplace=True)

# %%
df
# Out:
#      symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0            3      gas        std        two  convertible        rwd
# 1            3      gas        std        two  convertible        rwd
# 2            1      gas        std        two    hatchback        rwd
# 3            2      gas        std       four        sedan        fwd
# 4            2      gas        std       four        sedan        4wd
# ..         ...      ...        ...        ...          ...        ...
# 200         -1      gas        std       four        sedan        rwd
# 201         -1      gas      turbo       four        sedan        rwd
# 202         -1      gas        std       four        sedan        rwd
# 203         -1   diesel      turbo       four        sedan        rwd
# 204         -1      gas      turbo       four        sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# ...

# %% [markdown]
# # Converting fueltype into numerical using map() function

# %%
df['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df['fueltype']=df['fueltype'].map({'gas':1,'diesel':2})

# %%
df
# Out:
#      symboling  fueltype aspiration doornumber      carbody drivewheel  \
# 0            3         1        std        two  convertible        rwd
# 1            3         1        std        two  convertible        rwd
# 2            1         1        std        two    hatchback        rwd
# 3            2         1        std       four        sedan        fwd
# 4            2         1        std       four        sedan        4wd
# ..         ...       ...        ...        ...          ...        ...
# 200         -1         1        std       four        sedan        rwd
# 201         -1         1      turbo       four        sedan        rwd
# 202         -1         1        std       four        sedan        rwd
# 203         -1         2      turbo       four        sedan        rwd
# 204         -1         1      turbo       four        sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# ...

# %% [markdown]
# # converting aspiration using map()

# %%
df['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df['aspiration']=df['aspiration'].map({'std':1,'turbo':2})

# %%
df
# Out:
#      symboling  fueltype  aspiration doornumber      carbody drivewheel  \
# 0            3         1           1        two  convertible        rwd
# 1            3         1           1        two  convertible        rwd
# 2            1         1           1        two    hatchback        rwd
# 3            2         1           1       four        sedan        fwd
# 4            2         1           1       four        sedan        4wd
# ..         ...       ...         ...        ...          ...        ...
# 200         -1         1           1       four        sedan        rwd
# 201         -1         1           2       four        sedan        rwd
# 202         -1         1           1       four        sedan        rwd
# 203         -1         2           2       four        sedan        rwd
# 204         -1         1           2       four        sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# ...

# %% [markdown]
# # Converting doornumber using map()

# %%
df['doornumber'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
df['doornumber'] = df['doornumber'].map({'two':2,'four':4})

# %%
df
# Out:
#      symboling  fueltype  aspiration  doornumber      carbody drivewheel  \
# 0            3         1           1           2  convertible        rwd
# 1            3         1           1           2  convertible        rwd
# 2            1         1           1           2    hatchback        rwd
# 3            2         1           1           4        sedan        fwd
# 4            2         1           1           4        sedan        4wd
# ..         ...       ...         ...         ...          ...        ...
# 200         -1         1           1           4        sedan        rwd
# 201         -1         1           2           4        sedan        rwd
# 202         -1         1           1           4        sedan        rwd
# 203         -1         2           2           4        sedan        rwd
# 204         -1         1           2           4        sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# ...

# %% [markdown]
# # Converting carbody using labelencoding

# %%
df['carbody'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['carbody']=le.fit_transform(df['carbody'])

# %%
df
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody drivewheel  \
# 0            3         1           1           2        0        rwd
# 1            3         1           1           2        0        rwd
# 2            1         1           1           2        2        rwd
# 3            2         1           1           4        3        fwd
# 4            2         1           1           4        3        4wd
# ..         ...       ...         ...         ...      ...        ...
# 200         -1         1           1           4        3        rwd
# 201         -1         1           2           4        3        rwd
# 202         -1         1           1           4        3        rwd
# 203         -1         2           2           4        3        rwd
# 204         -1         1           2           4        3        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# 0            front       88.6      168.8      64.1  ...         130
# ...

# %% [markdown]
# # Converting drivewheel using labelencoding

# %%
df['drivewheel'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df['drivewheel']=le.fit_transform(df['drivewheel'])

# %%
df
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           1           2        0           2
# 1            3         1           1           2        0           2
# 2            1         1           1           2        2           2
# 3            2         1           1           4        3           1
# 4            2         1           1           4        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           1           4        3           2
# 201         -1         1           2           4        3           2
# 202         -1         1           1           4        3           2
# 203         -1         2           2           4        3           2
# 204         -1         1           2           4        3           2
#
#     enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# ...

# %% [markdown]
# # Converting enginelocation using labelencoder

# %%
df['enginelocation'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
df['enginelocation']=le.fit_transform(df['enginelocation'])

# %%
df.dtypes
# Out:
# symboling             int64
# fueltype              int64
# aspiration            int64
# doornumber            int64
# carbody               int64
# drivewheel            int64
# enginelocation        int64
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# # Converting enginetype using labelencoder

# %%
df['enginetype'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df['enginetype']=le.fit_transform(df['enginetype'])

# %%
df.dtypes
# Out:
# symboling             int64
# fueltype              int64
# aspiration            int64
# doornumber            int64
# carbody               int64
# drivewheel            int64
# enginelocation        int64
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype            int64
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# # Converting cylindernumber using map()

# %%
df['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df['cylindernumber']=df['cylindernumber'].map({'four':4,'six':6,'five':5,'three':3,'twelve':12,'two':2,'eight':8})

# %%
df['cylindernumber']
# Out:
# 0      4
# 1      4
# 2      6
# 3      4
# 4      5
#       ..
# 200    4
# 201    4
# 202    6
# 203    6
# 204    4
# Name: cylindernumber, Length: 205, dtype: int64

# %% [markdown]
# # Converting fuelsystem using labelencoder

# %%
df['fuelsystem'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
df['fuelsystem'] = le.fit_transform(df['fuelsystem'])

# %%
  df.dtypes
# Out:
# symboling             int64
# fueltype              int64
# aspiration            int64
# doornumber            int64
# carbody               int64
# drivewheel            int64
# enginelocation        int64
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype            int64
# cylindernumber        int64
# enginesize            int64
# fuelsystem            int64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# # Scaling on peakrpm feature

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
df.iloc[:,20:21]=sc.fit_transform(df.iloc[:,20:21])

# %% [markdown]
# # Dividing data into x and y

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
x
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           1           2        0           2
# 1            3         1           1           2        0           2
# 2            1         1           1           2        2           2
# 3            2         1           1           4        3           1
# 4            2         1           1           4        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           1           4        3           2
# 201         -1         1           2           4        3           2
# 202         -1         1           1           4        3           2
# 203         -1         2           2           4        3           2
# 204         -1         1           2           4        3           2
#
#      enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# ...

# %% [markdown]
# # dividing x and y into train & testing

# %%
df
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           1           2        0           2
# 1            3         1           1           2        0           2
# 2            1         1           1           2        2           2
# 3            2         1           1           4        3           1
# 4            2         1           1           4        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           1           4        3           2
# 201         -1         1           2           4        3           2
# 202         -1         1           1           4        3           2
# 203         -1         2           2           4        3           2
# 204         -1         1           2           4        3           2
#
#      enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=123)

# %%
x_train
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 128          3         1           1           2        0           2
# 81           3         1           1           2        2           1
# 77           2         1           1           2        2           1
# 79           1         1           2           2        2           1
# 183          2         1           1           2        3           1
# ..         ...       ...         ...         ...      ...         ...
# 17           0         1           1           4        3           2
# 98           2         1           1           2        1           1
# 66           0         2           1           4        3           2
# 126          3         1           1           2        1           2
# 109          0         1           1           4        4           2
#
#      enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# ...

# %%
y_test
# Out:
# 88      9279.0
# 72     35056.0
# 114    17075.0
# 158     7898.0
# 163     8058.0
#         ...
# 133    12170.0
# 166     9538.0
# 41     12945.0
# 180    15690.0
# 90      7099.0
# Name: price, Length: 62, dtype: float64

# %%
x_test
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 88          -1         1           1           4        3           1
# 72           3         1           1           2        0           2
# 114          0         2           2           4        4           2
# 158          0         2           1           4        3           1
# 163          1         1           1           2        3           2
# ..         ...       ...         ...         ...      ...         ...
# 133          2         1           1           4        3           1
# 166          1         1           1           2        2           2
# 41           0         1           1           4        3           1
# 180         -1         1           1           4        3           2
# 90           1         2           1           2        3           1
#
#      enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# ...

# %% [markdown]
# # Performing LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train) # its used to train , its take x and repective y
# Out:
# LinearRegression()

# %%
lr.coef_  # its a value of m
# Out:
# array([ 1.33167380e+02,  1.10729558e+04, -4.15162559e+01,  2.49836465e+02,
#        -4.90562144e+02,  1.57399267e+03,  1.00445088e+04,  1.63999462e+02,
#        -2.06689931e+01,  5.65694052e+02,  1.44223517e+02,  1.22837665e+00,
#        -3.74094252e+01, -1.17997725e+03,  1.27419674e+02, -2.93895654e+02,
#        -4.29080394e+03, -3.12950758e+03, -5.55521539e+02,  4.92898612e+01,
#         8.07421088e+02, -5.51821589e+01,  7.29158671e+01])

# %%
y_pred=lr.predict(x_test) # its used to predict the value of y

# %%
y_pred
# Out:
# array([10623.19736964, 28830.2205349 , 21817.70720128,  8976.21601376,
#         7682.37773039, 10019.27935649,  9168.30496479,  5671.22601177,
#         5777.4088836 ,  6449.56944121,  7364.40117313, 15350.74036145,
#         6414.10266801,  6299.52424914,  7368.56583694, 10735.01028161,
#        11125.79265121,  8248.93279507,  7526.49535636,  6308.56595123,
#        13236.85706336,  8748.26149097,  4852.68318105,  6199.87789326,
#        21302.79539756, 20964.12183649,  7304.9062787 ,  7856.26502433,
#        31549.07638271,  7132.34361732, 10073.46040409,  9510.57377085,
#         5940.44810736,  9910.96096967, 12513.02775648,  9793.80428312,
#         5741.78596073,  6436.85110574, 10284.48930942, 16415.48587929,
#         6313.19727391, 16350.0884936 , 21370.35611335,  6223.82353996,
#        13788.07593937, 10291.93246272, 21911.70299211, 10476.99454711,
#        10320.40249401,  9437.94404198, 16388.55638334, 11188.87011927,
# ...

# %% [markdown]
# # Finding rmse and r^2

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
rmse = mean_squared_error(y_test,y_pred,squared=False) # by default squared=true i.e. mse,  for rmse squared=false

# %%
rmse
# Out:
# 2773.5467750715206

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7650125313093203

# %%
from sklearn.svm import SVR

# %%
sv=SVR(kernel='linear')

# %%
sv.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred=sv.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
rmse=mean_squared_error(y_test,y_pred,squared=False)

# %%
rmse
# Out:
# 2619.3355597444947

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7904170293634958
