# %%
li=[5,7,3,99,7.8,'python']

# %%
type(li)
# Out:
# list

# %%
li
# Out:
# [5, 7, 3, 99, 7.8, 'python']

# %%
li[5]
# Out:
# 'python'

# %%
li[-1]
# Out:
# 'python'

# %%
li=[9,7,12,26,99,63]

# %%
li[2:5]
# Out:
# [12, 26, 99]

# %%
li[1:4]
# Out:
# [7, 12, 26]

# %%
li[:5]
# Out:
# [9, 7, 12, 26, 99]

# %%
li[2:]
# Out:
# [12, 26, 99, 63]

# %%
li[:7]
# Out:
# [9, 7, 12, 26, 99, 63]

# %%
li[-5:-1]
# Out:
# [7, 12, 26, 99]

# %%
li[-6:5]
# Out:
# [9, 7, 12, 26, 99]

# %%
li[1:5:2]
# Out:
# [7, 26]

# %%
li[-6:-1:2]
# Out:
# [9, 12, 99]

# %%
li[5:1:-1]
# Out:
# [63, 99, 26, 12]

# %%
li[-1:1:-1]
# Out:
# [63, 99, 26, 12]

# %%
li[-5:4:-1]
# Out:
# []

# %%
li[:4:1]
# Out:
# [9, 7, 12, 26]

# %%
li[:4:-1]
# Out:
# [63]

# %%
li[2::1]
# Out:
# [12, 26, 99, 63]

# %%
li[2::-2]
# Out:
# [12, 9]

# %%
li.append('Kaif')

# %%
li
# Out:
# [9, 7, 12, 26, 99, 63, 'Kaif']

# %%
li.insert(2,101)

# %%
li
# Out:
# [9, 7, 101, 12, 26, 99, 63, 'Kaif']

# %%
li.remove('Kaif')

# %%
li
# Out:
# [9, 7, 101, 12, 26, 99, 63]

# %%
li.sort()

# %%
li
# Out:
# [7, 9, 12, 26, 63, 99, 101]

# %%
li.sort(reverse=True)

# %%
li
# Out:
# [101, 99, 63, 26, 12, 9, 7]

# %% [markdown]
# **Practise**

# %%
li=[9,27,74,99,53,48]

# %%
li[::-1]
# Out:
# [48, 53, 99, 74, 27, 9]

# %%
li[-6:2]
# Out:
# [9, 27]

# %%
li[-2::-2]
# Out:
# [53, 74, 9]

# %%
li[2:7:2]
# Out:
# [74, 53]

# %%
li[:4:3]
# Out:
# [9, 99]

# %%
li[:-5:-1]
# Out:
# [48, 53, 99, 74]

# %%
li[-6::2]
# Out:
# [9, 74, 53]

# %%
li[:0:-1]
# Out:
# [48, 53, 99, 74, 27]

# %%
li[-2:2:2]
# Out:
# []

# %%
li[5:-5:-1]
# Out:
# [48, 53, 99, 74]
