# %%
age=int(input('enter the age'))
# Out:
# enter the age20

# %%
if(age>=18):
  print('you are eligible to vote')
else:
  print('you are not eligible to vote')
# Out:
# you are eligible to vote

# %%
per=float(input('Enter  your 12th percentage'))
# Out:
# Enter  your 12th percentage57

# %%
if(per>=75):
  print('Distinction')

elif(per>=60):
  print('First class')

elif(per>=35):
  print('Second class')

else:
  print('Fail')
# Out:
# Second class

# %%
#WAP to check the given no is divisible by 5 or not

no=int(input('Enter a number'))

if(no %5==0):
  print(no,'is divisible by 5')

else:
   print(no, 'is not divisible by 5')
# Out:
# Enter a number17
# 17 is not divisible by 5

# %%
#wap a program to check the given no is divisible by 5 and 7
no=int(input('Enter a number'))

if(no%5==0 and no%7==0):
  print(no,'is divisible by 5 and 7')

else:
  print(no,'is not divisible by 5 and 7')
# Out:
# Enter a number69
# 69 is not divisible by 5 and 7

# %%
#wap a program to check the given no is divisible by 5 and 7
no=int(input('Enter a number'))

if(no%5==0 or no%7==0):
  print(no,'is divisible by 5 and 7')

else:
  print(no,'is not divisible by 5 and 7')
# Out:
# Enter a number25
# 25 is divisible by 5 and 7

# %% [markdown]
# **PRACTISE**

# %%
age=int(input('enter the age'))
# Out:
# enter the age60

# %%
if(age>=55):
  print('you are eligible for vote')
else:
  print('you are not eligible for vote')
# Out:
# you are eligible for vote

# %%
per=float(input('enter the percentage of student'))
# Out:
# enter the percentage of student33

# %%
if(per>=75):
  print('Distinction')
elif(per>=60):
  print('First class')
elif(per>=35):
  print('Second class')
else:
  print('Fail')
# Out:
# Fail

# %%
#WAP to check the given no is divisible by 3 or not

no=int(input('Enter a number'))

if(no %3==0):
  print(no,'is divisible by 3')

else:
   print(no, 'is not divisible by 3')
# Out:
# Enter a number20
# 20 is not divisible by 3

# %%
#wap a program to check the given no is divisible by 5 and 7

no=int(input('enter a number'))

if(no%5==0 and no%7==0):
  Print(no,'is divisible by 5 and 7')
else:
  print(no,'is not divisible by 5 and 7')
# Out:
# enter a number3
# 3 is not divisible by 5 and 7

# %%
#wap a program to check the given no is divisible by 3 and 5
no=int(input('Enter a number'))

if(no%3==0 or no%5==0):
  print(no,'is divisible by 3 and 5')

else:
  print(no,'is not divisible by 3 and 5')
# Out:
# Enter a number36
# 36 is divisible by 3 and 5
