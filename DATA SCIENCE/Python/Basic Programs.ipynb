# %%
# Write the program to take radius from the user and the area of the circle.

# %%
r=float(input('Enter radius of circle'))
# Out:
# Enter radius of circle4.7

# %%
area=3.14*r*r

# %%
print('Area of circle=',area)
# Out:
# Area of circle= 69.3626

# %%
'''Ex. (for the multiple comments) Write the program to take radius from the user
and
the area of the circle'''
# Out:
# 'Ex. (for the multiple comments) Write the program to take radius from the user\nand \nthe area of the circle'

# %%
# take l and b from the user and find the area of rectangle l*b

# %%
l=float(input('Enter l value'))
b=float(input('Enter b value'))

area=l*b
print('Area of rectangle',area)
# Out:
# Enter l value10
# Enter b value5
# Area of rectangle 50.0

# %% [markdown]
# **PRACTISE**

# %%
# Write the program to take radius from the user and the area of the circle.

r=float(input('enter the radius of circle'))
# Out:
# enter the radius of circle5.5

# %%
area=3.14*r*r

# %%
print('area of circle=',area)
# Out:
# area of circle= 94.985

# %%
# take l and b from the user and find the area of rectangle l*b
length=float(input('enter the value of l'))
breath=float(input('enter the value of b'))

area=length*breath
print('area of rectangle',area)
# Out:
# enter the value of l5
# enter the value of b7
# area of rectangle 35.0

# %%
# find the area of triangle value takes from the user
breath=float(input('enter the value of b'))
height=float(input('enter the value of h'))
area=(breath*height)/1/2
# Out:
# enter the value of b5
# enter the value of h7

# %%
print(area)
# Out:
# 17.5
