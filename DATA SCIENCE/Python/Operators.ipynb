# %%
# Arthrometric

# %%
5**3
# Out:
# 125

# %%
5*2
# Out:
# 10

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
25%5
# Out:
# 0

# %%
5%3
# Out:
# 2

# %%
125%10
# Out:
# 5

# %%
16%8
# Out:
# 0

# %%
1879%10
# Out:
# 9

# %% [markdown]
# # **PRACTISE**

# %%
7*2
# Out:
# 14

# %%
5+6
# Out:
# 11

# %%
9-7
# Out:
# 2

# %%
0/5
# Out:
# 0.0

# %%
6**2
# Out:
# 36

# %%
7%5
# Out:
# 2

# %%
5%7
# Out:
# 5

# %%
55%5
# Out:
# 0

# %%
9%3
# Out:
# 0

# %%
178%7
# Out:
# 3

# %%
1562%10
# Out:
# 2

# %%
3%9
# Out:
# 3

# %%
2%10
# Out:
# 2

# %%
10//3
# Out:
# 3

# %%
6//2
# Out:
# 3

# %%
2//6
# Out:
# 0

# %%
2//7
# Out:
# 0

# %%
3//9
# Out:
# 0

# %%
5//15
# Out:
# 0
