# %%
a,b=5,10

# %%
def add(x,y):
  return x+y

# %%
add(a,b)
# Out:
# 15

# %%
kaif=lambda x,y:x+y

# %%
kaif(10,2)
# Out:
# 12

# %%
demo=lambda x:(x+2)**2 #This is called one line function

# %%
demo(2)
# Out:
# 16
