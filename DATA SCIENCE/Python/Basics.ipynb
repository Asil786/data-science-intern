# %%
print('Believe in Yourself')
# Out:
# Believe in Yourself

# %%
print('My Name is Kaif Khan')
# Out:
# My Name is Kaif Khan

# %%
print('I came from Kalyan, \nBy train. ')
# Out:
# I came from Kalyan,
# By train.

# %%
print("I came from kalyan \t by train")
# Out:
# I came from kalyan 	 by train

# %%
a=5

# %%
b=9.6

# %%
c="python"

# %%
a
# Out:
# 5

# %%
b
# Out:
# 9.6

# %%
c
# Out:
# 'python'

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
print('value of a is',a)
# Out:
# value of a is 5

# %%
print(a,"is the value of a")
# Out:
# 5 is the value of a

# %%
print(a, "is the value of a","\nvalue of b is",b)
# Out:
# 5 is the value of a
# value of b is 9.6

# %%
print(a,'is the value of a \nvalue of b is',b)
# Out:
# 5 is the value of a
# value of b is 9.6

# %%
a=int(input("enter a number"))
# Out:
# enter a number6

# %%
a
# Out:
# 6

# %%
type(a)
# Out:
# int

# %%
a=int(float(input('enter a number')))
a
# Out:
# enter a number5.7
# 5

# %%
a=float(input('enter a number'))
a
# Out:
# enter a number7
# 7.0

# %% [markdown]
# # **PRACTISE**

# %%
print('practise session')
# Out:
# practise session

# %%
print('next line \nsession for practise')
# Out:
# next line
# session for practise

# %%
print('tab like space \t session for practise')
# Out:
# tab like space 	 session for practise
