# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(4,10):
  print(i)
# Out:
# 4
# 5
# 6
# 7
# 8
# 9

# %%
for i in range (2,10,2):
  print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
for i in range(5,15,4):
  print(i)
# Out:
# 5
# 9
# 13

# %%
for i in range(3,150,5):
  print(i)
# Out:
# 3
# 8
# 13
# 18
# 23
# 28
# 33
# 38
# 43
# 48
# 53
# 58
# 63
# 68
# 73
# 78
# 83
# 88
# 93
# 98
# 103
# 108
# 113
# 118
# 123
# 128
# 133
# 138
# 143
# 148

# %%
for i in range(5,0,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
for i in range(5,-1,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
for i in range(10,2,-2):
  print(i)
# Out:
# 10
# 8
# 6
# 4

# %%
for i in range(50,-1,-5):
  print(i)
# Out:
# 50
# 45
# 40
# 35
# 30
# 25
# 20
# 15
# 10
# 5
# 0

# %%
#find the factorial and get value from the user

# %%
f=1

n=int(input('enter the value'))

for i in range(1,n+1):
  f=f*i
print('factorial of',n,'=',f)
# Out:
# enter the value5
# factorial of 5 = 120

# %% [markdown]
# **Practise**

# %%
for a in range(7):
  print(a)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for b in range(2,6):
  print(b)
# Out:
# 2
# 3
# 4
# 5

# %%
for c in range(1,10,2):
  print(c)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for z in range(1,20,5):
  print(z)
# Out:
# 1
# 6
# 11
# 16

# %%
for i in range(7,150,8):
  print(i)
# Out:
# 7
# 15
# 23
# 31
# 39
# 47
# 55
# 63
# 71
# 79
# 87
# 95
# 103
# 111
# 119
# 127
# 135
# 143

# %%
for g in range(15,5,-1):
  print(g)
# Out:
# 15
# 14
# 13
# 12
# 11
# 10
# 9
# 8
# 7
# 6

# %%
for i in range(7,-1,-1):
  print(i)
# Out:
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
for i in range(20,2,-2):
  print(i)
# Out:
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4

# %%
for i in range(30,-1,-5):
  print(i)
# Out:
# 30
# 25
# 20
# 15
# 10
# 5
# 0

# %%
#find the factorial and get value from the user
f=1

n=int(input('enter the value'))
for i in range(1,n+1):
  f=f*i
print('factorial of ',n,'=',f)
# Out:
# enter the value4
# factorial of  4 = 24
